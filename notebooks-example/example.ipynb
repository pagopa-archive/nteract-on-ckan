# %%
import requests
import pandas as pd
from io import StringIO
pd.options.display.html.table_schema = True

# %%
url = "https://dati.regione.campania.it/catalogo/resources/causemorte.csv?format=csv" 
payload = ""
headers = {'authorization': 'Bearer YOU_MUST_BE_LOGGEDIN'}
response = requests.request("GET", url, data=payload, headers=headers)
Cause_di_morte_CSV = pd.read_csv(StringIO(response.text), sep=None, engine="python")
Cause_di_morte_CSV
# Out:
#                                         ï»¿CausaMorte  Caserta  Benevento  \
# 0                                         tubercolosi      1.0        1.0
# 1                              aids (malattia da hiv)      NaN        NaN
# 2                                      epatite virale     48.0       13.0
# 3             altre malattie infettive e parassitarie     42.0       39.0
# 4   tumori maligni delle labbra, cavitÃ  orale e f...     38.0       11.0
# 5                         tumori maligni dell'esofago      8.0       11.0
# 6                        tumori maligni dello stomaco    149.0       49.0
# 7      tumori maligni del colon, del retto e dell'ano    259.0       95.0
# 8   tumori maligni del fegato e dei dotti biliari ...    152.0       39.0
# 9                         tumori maligni del pancreas    135.0       32.0
# 10                       tumori maligni della laringe     41.0        7.0
# 11  tumori maligni della trachea, dei bronchi e de...    459.0      134.0
# ...

# %%
url = "https://dati.regione.campania.it/catalogo/resources/causemorte.csv?format=csv" 
payload = ""
headers = {'authorization': 'Bearer YOU_MUST_BE_LOGGEDIN'}
response = requests.request("GET", url, data=payload, headers=headers)
Cause_di_morte_CSV = pd.read_csv(StringIO(response.text), sep=None, engine="python")
Cause_di_morte_CSV
# Out:
#                                         ï»¿CausaMorte  Caserta  Benevento  \
# 0                                         tubercolosi      1.0        1.0
# 1                              aids (malattia da hiv)      NaN        NaN
# 2                                      epatite virale     48.0       13.0
# 3             altre malattie infettive e parassitarie     42.0       39.0
# 4   tumori maligni delle labbra, cavitÃ  orale e f...     38.0       11.0
# 5                         tumori maligni dell'esofago      8.0       11.0
# 6                        tumori maligni dello stomaco    149.0       49.0
# 7      tumori maligni del colon, del retto e dell'ano    259.0       95.0
# 8   tumori maligni del fegato e dei dotti biliari ...    152.0       39.0
# 9                         tumori maligni del pancreas    135.0       32.0
# 10                       tumori maligni della laringe     41.0        7.0
# 11  tumori maligni della trachea, dei bronchi e de...    459.0      134.0
# ...

# %%
url = "http://dati.consip.it/dataset/67bc8fc3-4544-4afc-a532-85829f6eb6b8/resource/a659c80b-ca6b-44ee-950b-4ede283d9f69/download/cataloghicoperturaterritorialetrentino.csv?format=csv" 
payload = ""
headers = {'authorization': 'Bearer YOU_MUST_BE_LOGGEDIN'}
response = requests.request("GET", url, data=payload, headers=headers)
Trentino_Alto_Adige = pd.read_csv(StringIO(response.text), sep=None, engine="python")
Trentino_Alto_Adige
# Out:
#        #Data_Competenza                            Denominazione_Fornitore  \
# 0            10/01/2020                       ACCORD HEALTHCARE ITALIA SRL
# 1            10/01/2020           KYOCERA DOCUMENT SOLUTIONS ITALIA S.P.A.
# 2            10/01/2020                                          IVECO SPA
# 3            10/01/2020  RTI - CONSORZIO INNOVA SOCIETA' COOPERATIVA, O...
# 4            10/01/2020                                 TELECOM ITALIA SPA
# 5            10/01/2020                                           OLIVETTI
# 6            10/01/2020                                   ACS DATA SYSTEMS
# 7            10/01/2020                               SARTORI AMBIENTE SRL
# 8            10/01/2020                                        ALEIXA SRLS
# 9            10/01/2020                                             REMIDA
# 10           10/01/2020                                            GRAITEC
# ...
