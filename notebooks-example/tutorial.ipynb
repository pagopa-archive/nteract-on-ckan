# %% [markdown]
# # Getting started tutorial
#
#
# ### Intro
# We will go thought some simple steps to start with playing with pdnd-nteract, only for describing the basic steps and functionalities. In the next weeks we hope to publish some interesting use cases that could be also used for teaching and education.
#
#
#
# Of course you must have launched nteract from the daf-develop branch. In case read [here](https://github.com/teamdigitale/nteract/blob/daf-develop/pdnd-nteract.md)
#
#
#
# Once launched nteract start a new python 3 notebook
#
# From menu choose a markdown cell and write some markdown code.
#
#   or choose a code cell and copy and paste the code below and run the cell
#   ```
#   a = 1 + 1
#   a
#   ```

# %%
a = 1 + 1 
a
# Out:
# 2

# %% [markdown]
# Ok if is working now you can register into [PDND](https://dataportal.daf.teamdigitale.it/#/register) or if you have already an account login in by click on the LOGIN button.

# %%
from IPython.display import Image
Image(url='https://raw.githubusercontent.com/teamdigitale/nteract/daf-develop/pdnd-tutorials/img/login.png')
# Out:
# <img src="https://raw.githubusercontent.com/teamdigitale/nteract/daf-develop/pdnd-tutorials/img/login.png"/>

# %% [markdown]
# Import some python libraries
# ```
# import requests
# import pandas as pd
# from io import StringIO
# pd.options.display.html.table_schema = True
# ```

# %%
import requests
import pandas as pd
from io import StringIO
pd.options.display.html.table_schema = True

# %% [markdown]
# Once logged in, now you can search for Italian public datasets by clicking on the lens on the right of a new code cell. Try to look for *ricette* you will see something like that:

# %%
from IPython.display import Image
Image(url='https://raw.githubusercontent.com/teamdigitale/nteract/daf-develop/pdnd-tutorials/img/search.png')
# Out:
# <img src="https://raw.githubusercontent.com/teamdigitale/nteract/daf-develop/pdnd-tutorials/img/search.png"/>

# %% [markdown]
# Run the cell and you should see something like that:

# %%
url = "https://api.daf.teamdigitale.it/dataset-manager/v1/dataset/daf%3A%2F%2Fopendata%2Fprovinciatrento_o_ricette_tipiche_trentine_1?format=json" 
payload = ""
headers = {'authorization': 'Bearer YOU_MUST_BE_LOGGEDIN'}
response = requests.request("GET", url, data=payload, headers=headers)
provinciatrento_o_ricette_tipiche_trentine_1 = pd.read_json(StringIO(response.text))
provinciatrento_o_ricette_tipiche_trentine_1
# Out:
#      Category                                         Ingredient  \
# 0     Secondi  1 cotechino di maiale trentino, 500 gr. di fag...
# 1       Primi  250 gr. di farina bianca ; 50 gr. di farina sa...
# 2     Secondi  1/2 kg. di crauti trentini;1 hg. di pancetta a...
# 3     Secondi  1 fagiano ben frollato ; 100 gr. di pancetta n...
# 4       Primi  100 gr. di Speck trentino;70 gr. di burro;150 ...
# 5   Antipasti  400 gr. di Caprino trentino ;16-20 foglie di v...
# 6   Antipasti  200 gr. di formaggio Casolèt della Val di Sole...
# 7   Antipasti  150 gr. di formaggio Casolèt;1 pera;1 fico sec...
# 8     Secondi  750 gr. di cipolle;125 gr. di formaggio Fontal...
# 9   Antipasti  1 peperone;100 gr. di porri;100 gr. di sedano;...
# 10    Secondi  600 gr. di Provola affumicata trentina;Nostran...
# 11      Primi  500 gr. di pane a dadini;100 gr. di formaggio ...
# 12    Secondi  600 gr. di Tosèla;100 gr. di burro;polenta gia...
# 13    Secondi  1 fetta di formaggio Tre Valli tagliata spessa...
# 14  Antipasti  8 carciofi;50 gr. di formaggio Vezzena vecchio...
# 15  Antipasti  400 gr. di spinaci;150 gr. di formaggio Vezzen...
# 16    Secondi  1 kg. di crauti freschi trentini;una mela gold...
# 17        NaN  600 gr. di farina di mais di Storo;2 litri cir...
# 19  Preparazione Si taglia il pane raffermo a dadi...        20
# 20  Preparazione Mettere in ammollo nel latte tiep...        21
# 21  Preparazione Dopo aver fatto amalgamare gli in...        22
# 22  Preparazione Dopo aver amalgamato gli ingredie...        23
# 23  "Preparazione L'impasto così ottenuto va lavor...        24
# 24  Preparazione Si prende una libbra di mandorle ...        25
# 25  Preparazione Per prima cosa si devono mondare ...        26
# 26  Preparazione Si inizia sbattendo in una terrin...        27
# 27  Preparazione Prendere le Alborelle e privarle ...        28
# 28  Preparazione La trota, questo eccellente salmo...        29
# 29  Preparazione Sbucciare le mele e tagliarle a f...        30
# 30  "Preparazione Sbucciare le pere, tagliarle a l...        31
# 31  Preparazione Si scioglie il lievito di birra i...        32
# 32  Preparazione Si impasta la farina con il lievi...        33
# 33  Preparazione Si taglia il pane raffermo a dadi...        34
# 34  Preparazione Mettere la farina di castagne in ...        35
# 35  Preparazione Si impasta la farina con l'uovo i...        36
# 36  Preparazione Si taglia a pezzettini la verdura...        37
# 37  Preparazione Lavare accuratamente le noci, che...        38
# 38  Preparazione Si impastano la farina di frument...        39
# 39  Preparazione Si impastano la farina di frument...        40
# 40  Preparazione Si impastano la farina di frument...        41
# 41  Preparazione Si impasta la farina di frumento ...        42
# 42  Preparazione Si impastano la farina con il lie...        43
# 43  "Preparazione Sbucciare le patate e lessarle i...        44
# 44  "Preparazione Si impasta la farina con i tuorl...        45
# 45  "Preparazione Si impastano la farina, i rossi ...        46
# 46  Preparazione Sbattere in una scodella i tuorli...        47
# 47  Preparazione Si impasta la farina con le uova ...        48
# 48  Preparazione Si impasta la farina con le uova ...        49
#
#                                              Title
# 0                   Cotechino con fasoi en bronzon
# 1                                         Smacafam
# 2            Zuppa di Crauti e Pancetta affumicata
# 3                    Fagiano con Pancetta nostrana
# 4                   Garganelli allo Speck trentino
# 5               Caprino trentino in foglie di vite
# 6                 Mele, Noci del Bleggio e Casolèt
# 7                                   Casolèt e pere
# 8             Cipolle gratinate al Fontal trentino
# 9                        Porri e Nostrano de Casel
# 10     Provola affumicata e altro formaggio fritto
# 11                       Gnocchi allo Spetz Tsaorì
# 12                                Polenta e Tosèla
# 13                 Formaggio Tre Valli alla grappa
# 14                              Carciofi e Vezzena
# 15                         Spinaci crudi e Vezzena
# 16                        Crauti trentini e maiale
# 17                                         Polenta
# 18                                 Canederli dolci
# 19                         Canederli alla trentina
# 20                                  Strangolapreti
# 21                                 Bechi-panzalini
# 22                                            Bina
# 23                                       Gramolato
# 24                                 Basini de Trent
# 25                              Torta de fregolòti
# 26                                          Zelten
# 27                                        El sìsam
# 28                Trota alle mele della Val di Non
# 29  Frittelle di mele alla grappa giovane trentina
# 30                              Pere agli amaretti
# 31                                        Brazedel
# 32                                          Buzòla
# 33                          Canederli al formaggio
# 34                                    Castagnaccio
# 35                                         Crofani
# 36                                 Minestra d'orzo
# 37                                          Nocino
# 38                              Pan co' le frìtole
# 39                                   Pan de Segàla
# 40                                     Pan de Sòrc
# 41                                  Pane de Molche
# 42                                           Pinza
# 43                               Polenta di patate
# 44                    Stràuli o Stràboli o Fortaie
# 45                                         Strudel
# 46                                 Torta di carote
# 47                           Tortolèti coi puriòni
# 48                                        Grostoli

# %% [markdown]
# **Congratulations** now you can play and analyse some different datasets. If you will do something interesting please contact us.
